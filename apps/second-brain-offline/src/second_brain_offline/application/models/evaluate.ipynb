# %% [markdown]
# ### Installation

# %%
# %%capture
# !pip install vllm==0.7.1 evaluate==0.4.3 rouge_score==0.1.2 bitsandbytes==0.45.1

# %% [markdown]
# ### Global Variables

# %%
dataset_id = (
    input("enter your huggingface dataset_id here, : ")
    or "pauliusztin/second_brain_course_summarization_task"
)
print(f"{dataset_id=}")

model_id = ( 
    input("enter your huggingface smmarization model id here, :")
    or "Parth19Dhimmar/Meta-Llama-3.1-8B-Instruct-second-brain"
)
print(f"{model_id=}")
# Out:
# dataset_id='pauliusztin/second_brain_course_summarization_task'
# model_id='Parth19Dhimmar/Meta-Llama-3.1-8B-Instruct-second-brain'

# %%
import torch


def get_gpu_info() -> str | None:
    """Gets GPU device name if available.

    Returns:
        str | None: Name of the GPU device if available, None if no GPU is found.
    """
    if not torch.cuda.is_available():
        return None

    gpu_name = torch.cuda.get_device_properties(0).name

    return gpu_name


active_gpu_name = get_gpu_info()

print("GPU type:")
print(active_gpu_name)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import torch
#       4 def get_gpu_info() -> str | None:
#       5     """Gets GPU device name if available.
#       6
#       7     Returns:
#       8         str | None: Name of the GPU device if available, None if no GPU is found.
#       9     """
#
# File d:\Projects\SecondBrain\venv\Lib\site-packages\torch\__init__.py:2193
#    2177 ################################################################################
#    2178 # Import most common subpackages
#    2179 ################################################################################
#    (...)   2184
#    2185 # needs to be before import torch.nn as nn to avoid circular dependencies
#    2186 from torch.autograd import (  # usort: skip
#    2187     enable_grad as enable_grad,
#    2188     inference_mode as inference_mode,
#    2189     no_grad as no_grad,
#    2190     set_grad_enabled as set_grad_enabled,
#    2191 )
# -> 2193 from torch import (
#    2194     __config__ as __config__,
#    2195     __future__ as __future__,
#    2196     _awaits as _awaits,
#    2197     accelerator as accelerator,
#    2198     autograd as autograd,
#    2199     backends as backends,
#    2200     cpu as cpu,
#    2201     cuda as cuda,
#    2202     distributed as distributed,
#    2203     distributions as distributions,
#    2204     fft as fft,
#    2205     futures as futures,
#    2206     hub as hub,
#    2207     jit as jit,
#    2208     linalg as linalg,
#    2209     mps as mps,
#    2210     mtia as mtia,
#    2211     multiprocessing as multiprocessing,
#    2212     nested as nested,
#    2213     nn as nn,
#    2214     optim as optim,
#    2215     overrides as overrides,
#    2216     profiler as profiler,
#    2217     sparse as sparse,
#    2218     special as special,
#    2219     testing as testing,
#    2220     types as types,
#    2221     utils as utils,
#    2222     xpu as xpu,
#    2223 )
#    2224 from torch.signal import windows as windows
#    2227 # Quantized, sparse, AO, etc. should be last to get imported, as nothing
#    2228 # is expected to depend on them.
#
# File d:\Projects\SecondBrain\venv\Lib\site-packages\torch\nested\__init__.py:21
#      11 __all__ = [
#      12     "to_padded_tensor",
#      13     "as_nested_tensor",
#    (...)     17     "masked_select",
#      18 ]
#      20 # Allowlist these for weights_only load of NJT
# ---> 21 from ._internal.nested_tensor import _rebuild_njt, NestedTensor as _NestedTensor
#      24 torch.serialization.add_safe_globals([_NestedTensor, _rebuild_njt])
#      27 def as_nested_tensor(
#      28     ts: Union[Tensor, list[Tensor], tuple[Tensor, ...]],
#      29     dtype: Optional[DType] = None,
#      30     device: Optional[Device] = None,
#      31     layout=None,
#      32 ) -> Tensor:
#
# File d:\Projects\SecondBrain\venv\Lib\site-packages\torch\nested\_internal\nested_tensor.py:7
#       5 from torch._C import DispatchKey, DispatchKeySet
#       6 from torch._prims_common import is_expandable_to
# ----> 7 from torch.nested._internal.nested_int import NestedIntNode
#       8 from torch.utils.weak import WeakTensorKeyDictionary
#      11 _tensor_id_counter = 0
#
# File d:\Projects\SecondBrain\venv\Lib\site-packages\torch\nested\_internal\nested_int.py:4
#       1 from typing import *  # noqa: F403
#       3 import torch
# ----> 4 from torch.fx.experimental._constant_symnode import ConstantIntNode
#       7 __all__ = ["NestedIntNode"]
#      10 # Python version of aten/src/ATen/core/NestedIntSymNodeImpl.cpp
#
# File d:\Projects\SecondBrain\venv\Lib\site-packages\torch\fx\__init__.py:88
#       1 r'''
#       2 FX is a toolkit for developers to use to transform ``nn.Module``
#       3 instances. FX consists of three main components: a **symbolic tracer,**
#    (...)     84 repository.
#      85 '''
#      87 from torch.fx import immutable_collections
# ---> 88 from torch.fx._symbolic_trace import (  # noqa: F401
#      89     PH,
#      90     ProxyableClassMeta,
#      91     symbolic_trace,
#      92     Tracer,
#      93     wrap,
#      94 )
#      95 from torch.fx.graph import CodeGen, Graph  # noqa: F401
#      96 from torch.fx.graph_module import GraphModule
#
# File d:\Projects\SecondBrain\venv\Lib\site-packages\torch\fx\_symbolic_trace.py:22
#      19 from torch._library.fake_class_registry import FakeScriptObject
#      21 from ._compatibility import compatibility
# ---> 22 from ._lazy_graph_module import _make_graph_module
#      23 from .graph import _PyTreeCodeGen, _PyTreeInfo, Graph
#      24 from .graph_module import GraphModule
#
# File d:\Projects\SecondBrain\venv\Lib\site-packages\torch\fx\_lazy_graph_module.py:4
#       1 # mypy: allow-untyped-defs
#       2 from contextlib import contextmanager
# ----> 4 from torch.fx.graph_module import (
#       5     _format_import_block,
#       6     GraphModule,
#       7     reduce_graph_module,
#       8     reduce_package_graph_module,
#       9 )
#      10 from torch.package import PackageExporter, sys_importer
#      12 from ._compatibility import compatibility
#
# File d:\Projects\SecondBrain\venv\Lib\site-packages\torch\fx\graph_module.py:20
#      17 from torch.package import Importer, PackageExporter, PackageImporter, sys_importer
#      19 from ._compatibility import compatibility
# ---> 20 from .graph import (
#      21     _custom_builtins,
#      22     _is_from_torch,
#      23     _override_sym_repr,
#      24     _PyTreeCodeGen,
#      25     Graph,
#      26     PythonCode,
#      27 )
#      30 __all__ = [
#      31     "reduce_graph_module",
#      32     "reduce_package_graph_module",
#      33     "reduce_deploy_graph_module",
#      34     "GraphModule",
#      35 ]
#      37 _USER_PRESERVED_ATTRIBUTES_KEY = "_user_preserved_attributes"
#
# File d:\Projects\SecondBrain\venv\Lib\site-packages\torch\fx\graph.py:28
#      26 from ._compatibility import compatibility
#      27 from .immutable_collections import immutable_dict
# ---> 28 from .node import _get_qualified_name, _type_repr, Argument, Node, Target
#      31 __all__ = ["PythonCode", "CodeGen", "Graph"]
#      33 if TYPE_CHECKING:
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:995, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1091, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1190, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
if active_gpu_name and "T4" in active_gpu_name:
    evaluation_steps = 8
elif active_gpu_name and ("A100" in active_gpu_name or "L4" in active_gpu_name):
    evaluation_steps = 8
elif active_gpu_name:
    evaluation_steps = 8
else:
    raise ValueError("No Nvidia GPU found.")

# %% [markdown]
# ### Load Finetuned LLM

# %%
# vLLM is a fast and easy-to-use library for LLM inference and serving.
from vllm import LLM

llm = LLM(
    model="Parth19Dhimmar/Meta-Llama-3.1-8B-Instruct-second-brain",
    max_model_len=4096,
    dtype="float16",
    quantization="bitsandbytes",
    load_format="bitsandbytes",
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 # vLLM is a fast and easy-to-use library for LLM inference and serving.
# ----> 2 from vllm import LLM
#       4 llm = LLM(
#       5     model="Parth19Dhimmar/Meta-Llama-3.1-8B-Instruct-second-brain",
#       6     max_model_len=4096,
#    (...)      9     load_format="bitsandbytes",
#      10 )
#
# ModuleNotFoundError: No module named 'vllm'
